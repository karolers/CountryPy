# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# this is the library that we will use to create break times in order to mimic human behaviour 
import time

# this library will be used for getting your credentials but keeping them hidden in the script 
from getpass import getpass

# these are the Classes we will use for interaction with a webpage
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
#from webdriver_manager.chrome import ChromeDriverManager

# library for interacting with the operating system
import os

# you know pandas it's your best buddy 
import pandas as pd

# %%
# open the webdriver
url = 'https://www.nationsonline.org/oneworld/IATA_Codes/airport_code_list.htm'
#driver = webdriver.Chrome('chromedriver')
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# %%
driver.get(url)

# %%
data =BeautifulSoup(driver.page_source)

# %% [markdown]
# ## A

# %%
table = data.find_all('table')
table1 = table[0].find_all('td')
tabletext = [i.text for i in table1]

# %%
clean =[x for x in tabletext if len(x) > 1]

# %%
len(clean)
# Out:
# 360

# %%
f = clean[::3]
s = clean[1::3]
t = clean[2::3]

# %%
capcode_a = pd.DataFrame(list(zip(f,s,t)), columns=['city', 'country', 'code'])

# %%
capcode_a
# Out:
#                                        city         country code
# 0                                    Aarhus         Denmark  AAR
# 1                                    Abadan            Iran  ABD
# 2                                    Abeche            Chad  AEH
# 3                                  Aberdeen  United Kingdom  ABZ
# 4                            Aberdeen (SD)              USA  ABR
# ..                                      ...             ...  ...
# 115                                Aurillac          France  AUR
# 116  Austin (TX) - Austin-Bergstrom Airport             USA  AUS
# 117                                 Ayawasi       Indonesia  AYW
# 118                  Ayers Rock - Connellan       Australia  AYQ
# 119                                     Ayr       Australia  AYR
#
# [120 rows x 3 columns]

# %% [markdown]
# ## B

# %%
table = data.find_all('table')
table1 = table[1].find_all('td')
tabletext = [i.text for i in table1]
clean =[x for x in tabletext if len(x) > 1]

f = clean[::3]
s = clean[1::3]
t = clean[2::3]

capcode_b = pd.DataFrame(list(zip(f,s,t)), columns=['city', 'country', 'code'])
capcode_b
# Out:
#                                                  city      country code
# 0                                             Badajoz        Spain  BJZ
# 1              Bagdad - Baghdad International Airport         Iraq  BGW
# 2                                            Bagdogra        India  IXB
# 3    Bahamas - Lynden Pindling International Airport   The Bahamas  NAS
# 4                                          Bahawalpur     Pakistan  BHV
# ..                                                ...          ...  ...
# 145                                     Burbank (CA)           USA  BUR
# 146                                     Burlington IA          USA  BRL
# 147                                  Burlington (VT)           USA  BTV
# 148                                  Burnie (Wynyard)    Australia  BWT
# 149                                       Butte (MT)           USA  BTM
#
# [150 rows x 3 columns]

# %% [markdown]
# C

# %%
table = data.find_all('table')
table1 = table[2].find_all('td')
tabletext = [i.text for i in table1]
clean =[x for x in tabletext if len(x) > 1]

f = clean[::3]
s = clean[1::3]
t = clean[2::3]

capcode_c = pd.DataFrame(list(zip(f,s,t)), columns=['city', 'country', 'code'])
capcode_c
# Out:
#                                                city               country code
# 0                                           Cabinda                Angola  CAB
# 1                                          Cagliari                 Italy  CAG
# 2                                            Cairns             Australia  CNS
# 3              Cairo - Cairo International Airport                  Egypt  CAI
# 4                                   Calama - El Loa                 Chile  CJC
# ..                                              ...                   ...  ...
# 123  Cuiaba - Marechal Rondon International Airport                Brazil  CGB
# 124                                        Culiacan                Mexico  CUL
# 125         Curacao - Curaçao International Airport  Netherlands Antilles  CUR
# 126    Curitiba - Afonso Pena International Airport                Brazil  CWB
# 127                                            Cuyo           Philippines  CYU
#
# [128 rows x 3 columns]

# %% [markdown]
# D

# %%
table = data.find_all('table')
table1 = table[3].find_all('td')
tabletext = [i.text for i in table1]
clean =[x for x in tabletext if len(x) > 1]

f = clean[::3]
s = clean[1::3]
t = clean[2::3]

capcode_d = pd.DataFrame(list(zip(f,s,t)), columns=['city', 'country', 'code'])
capcode_d
# Out:
#                                                  city             country code
# 0   Dakar - Léopold Sédar Senghor International Ai...             Senegal  DKR
# 1                                             Dalaman              Turkey  DLM
# 2                                               Dalby           Australia  DBY
# 3           Dalian - Zhoushuizi International Airport  Liaoning, PR China  DLC
# 4                            Dallas (TX) , Love Field                 USA  DAL
# ..                                                ...                 ...  ...
# 59                                             Durban        South Africa  DUR
# 60            Dushanbe (Duschanbe) - Dushanbe Airport          Tajikistan  DYU
# 61                                 Dutch Harbor (AK)                  USA  DUT
# 62                                             Dysart           Australia  DYA
# 63                                           Dzaoudzi             Mayotte  DZA
#
# [64 rows x 3 columns]

# %% [markdown]
# E

# %%
table = data.find_all('table')
table1 = table[4].find_all('td')
tabletext = [i.text for i in table1]
clean =[x for x in tabletext if len(x) > 1]

f = clean[::3]
s = clean[1::3]
t = clean[2::3]

capcode_e = pd.DataFrame(list(zip(f,s,t)), columns=['city', 'country', 'code'])
capcode_e
# Out:
#                                               city             country code
# 0                                      East London        South Africa  ELS
# 1                                    Easter Island               Chile  IPC
# 2                                 Eau Clarie (WI)                  USA  EAU
# 3                    Edinburgh - Edinburgh Airport        Scotland, UK  EDI
# 4                                         Edmonton              Canada  YEA
# 5                          Edmonton, International              Canada  YEG
# 6                              Edmonton, Municipal              Canada  YXD
# 7                                      Egilsstadir             Iceland  EGS
# 8                                        Eindhoven         Netherlands  EIN
# 9   Samana - Samaná El Catey International Airport  Dominican Republic  AZS
# 10                    Elba Island, Marina Di Campo               Italy  EBA
# ...

# %% [markdown]
# F

# %%
table = data.find_all('table')
table1 = table[5].find_all('td')
tabletext = [i.text for i in table1]
clean =[x for x in tabletext if len(x) > 1]

f = clean[::3]
s = clean[1::3]
t = clean[2::3]

capcode_f = pd.DataFrame(list(zip(f,s,t)), columns=['city', 'country', 'code'])
capcode_f
# Out:
#                                                  city  \
# 0                                     Fairbanks (AK)
# 1                                Fair Isle (Shetland)
# 2                                          Faisalabad
# 3                                    Fargo (ND) (MN)
# 4                                    Farmington (NM)
# 5                                                Faro
# 6                             Faroer - Vágar Airport
# 7                                  Fayetteville (AR)
# 8                        Fayetteville/Ft. Bragg (NC)
# 9                                                 Fes
# 10                                             Figari
# 11                                    Flagstaff (AZ)
# 12                                          Flin Flon
# 13                                        Flint (MI)
# 14              Florence (Firenze) - Peretola Airport
# 15                                     Florence (SC)
# ...

# %% [markdown]
# G

# %%
table = data.find_all('table')
table1 = table[6].find_all('td')
tabletext = [i.text for i in table1]
clean =[x for x in tabletext if len(x) > 1]

f = clean[::3]
s = clean[1::3]
t = clean[2::3]

capcode_g = pd.DataFrame(list(zip(f,s,t)), columns=['city', 'country', 'code'])
capcode_g
# Out:
#       city                                            country       code
# 0   \n\n\n  Gaborone - Sir Seretse Khama International Air...   Botswana
# 1      GBE                                      Gadsden (AL)         USA
# 2      GAD                                   Gainesville (FL)        USA
# 3      GNV                                             Galway    Ireland
# 4      GWY                                             Gander     Canada
# ..     ...                                                ...        ...
# 70     ULU                       Gunnison/Crested Butte (CO)         USA
# 71     GUC                                           Guwahati      India
# 72     GAU                                             Gwadar   Pakistan
# 73     GWD                                              Gweru   Zimbabwe
# 74     GWE                                             Gympie  Australia
#
# [75 rows x 3 columns]

# %% [markdown]
# H

# %%
table = data.find_all('table')
table1 = table[7].find_all('td')
tabletext = [i.text for i in table1]
clean =[x for x in tabletext if len(x) > 1]

f = clean[::3]
s = clean[1::3]
t = clean[2::3]

capcode_h = pd.DataFrame(list(zip(f,s,t)), columns=['city', 'country', 'code'])
capcode_h
# Out:
#                                               city   country code
# 0                                     Hachijo Jima     Japan  HAC
# 1             Hagåtña - Guam International Airport      Guam  GUM
# 2                                            Haifa    Israel  HFA
# 3                                     Haines (AK)        USA  HNS
# 4                                         Hakodate     Japan  HKD
# ..                                             ...       ...  ...
# 63                            Hwange National Park  Zimbabwe  HWN
# 64                                   Hyannis (MA)        USA  HYA
# 65                                  Hydaburg (AK)        USA  HYG
# 66  Hyderabad - Rajiv Gandhi International Airport     India  HYD
# 67                                       Hyderabad  Pakistan  HDD
#
# [68 rows x 3 columns]

# %% [markdown]
# I

# %%
table = data.find_all('table')
table1 = table[8].find_all('td')
tabletext = [i.text for i in table1]
clean =[x for x in tabletext if len(x) > 1]

f = clean[::3]
s = clean[1::3]
t = clean[2::3]

capcode_i= pd.DataFrame(list(zip(f,s,t)), columns=['city', 'country', 'code'])
capcode_i
# Out:
#                                                 city         country  \
# 0                                              Ibiza     Ibiza/Spain
# 1                                   Idaho Falls (ID)             USA
# 2                                  Iguazu, Cataratas       Argentina
# 3                                       Ile des Pins   New Caledonia
# 4                                           Ile Ouen   New Caledonia
# 5                                      Iliamna (AK)              USA
# 6                                     Imperial (CA)              USA
# 7                                       Incercargill     New Zealand
# 8             Incheon, Incheon International Airport     Korea South
# 9                    Indianapolis (IN) International             USA
# 10                                            Ingham       Australia
# 11                                         Innisfail       Australia
# 12                           Innsbruck - Kranebitten         Austria
# ...

# %% [markdown]
# J

# %%
table = data.find_all('table')
table1 = table[9].find_all('td')
tabletext = [i.text for i in table1]
clean =[x for x in tabletext if len(x) > 1]

f = clean[::3]
s = clean[1::3]
t = clean[2::3]

capcode_j = pd.DataFrame(list(zip(f,s,t)), columns=['city', 'country', 'code'])
capcode_j
# Out:
#                                            city    country code
# 0                            Jackson Hole (WY)         USA  JAC
# 1             Jackson (MI) - Reynolds Municipal        USA  JXN
# 2                                Jackson,  MN          USA  MJQ
# 3         Jackson (MS) - Jackson Internationall        USA  JAN
# 4               Jackson (MS) - Hawkins Field           USA  HKS
# ..                                          ...        ...  ...
# 102  Juneau (AK) - Juneau International Airport        USA  JNU
# 103                                       Junin  Argentina  JNI
# 104                                   Juticalpa   Honduras  JUT
# 105                                     Jwaneng   Botswana  JWA
# 106                       Jyväskylä (Jyvaskyla)    Finland  JYV
#
# [107 rows x 3 columns]

# %% [markdown]
# k

# %%
table = data.find_all('table')
table1 = table[10].find_all('td')
tabletext = [i.text for i in table1]
clean =[x for x in tabletext if len(x) > 1]

f = clean[::3]
s = clean[1::3]
t = clean[2::3]

capcode_k = pd.DataFrame(list(zip(f,s,t)), columns=['city', 'country', 'code'])
capcode_k
# Out:
#                               city      country code
# 0    Kabul - Khwaja Rawash Airport  Afghanistan  KBL
# 1                        Kagoshima        Japan  KOJ
# 2                    Kahramanmaras       Turkey  KCM
# 3                     Kahului (HI)          USA  OGG
# 4                          Kajaani      Finland  KAJ
# ..                             ...          ...  ...
# 104           Kuujjuaq (FortChimo)       Canada  YVP
# 105                   Kuujjuarapik       Canada  YGW
# 106                        Kuusamo      Finland  KAO
# 107  Kuwait - Kuwait International       Kuwait  KWI
# 108                          Kyoto        Japan  UKY
#
# [109 rows x 3 columns]

# %% [markdown]
# L

# %%
table = data.find_all('table')
table1 = table[11].find_all('td')
tabletext = [i.text for i in table1]
clean =[x for x in tabletext if len(x) > 1]

f = clean[::3]
s = clean[1::3]
t = clean[2::3]

capcode_l = pd.DataFrame(list(zip(f,s,t)), columns=['city', 'country', 'code'])
capcode_l
# Out:
#                                    city         country code
# 0                                  Labe          Guinea  LEK
# 1                  Labouchere Bay (AK)              USA  WLB
# 2                                Labuan        Malaysia  LBU
# 3                       Lac Brochet, MB          Canada  XLB
# 4                             La Coruna           Spain  LCG
# ..                                  ...             ...  ...
# 112                Lvov (Lwow, Lemberg)         Ukraine  LWO
# 113   Lydd - Lydd International Airport  United Kingdom  LYX
# 114                     Lynchburg (VA)              USA  LYH
# 115  Lyon - Lyon-Saint Exupéry Airport           France  LYS
# 116  Lyons (KS) - Rice County Municipal             USA  LYO
#
# [117 rows x 3 columns]

# %% [markdown]
# M

# %%
table = data.find_all('table')
table1 = table[12].find_all('td')
tabletext = [i.text for i in table1]
clean =[x for x in tabletext if len(x) > 1]

f = clean[::3]
s = clean[1::3]
t = clean[2::3]

capcode_m= pd.DataFrame(list(zip(f,s,t)), columns=['city', 'country', 'code'])
capcode_m
# Out:
#      city                                            country              code
# 0    \n\n                                  Maastricht/Aachen       Netherlands
# 1    MST   Macapa - Alberto Alcolumbre International Airport            Brazil
# 2     MCP                Macau - Macau International Airport  Macau, China SAR
# 3     MFM  Maceio - Zumbi dos Palmares International Airport            Brazil
# 4     MCZ                                             Mackay         Australia
# ..    ...                                                ...               ...
# 181   JMK               Myrtle Beach (SC) - Myrtle Beach AFB               USA
# 182   MYR           Myrtle Beach (SC) - Grand Strand Airport               USA
# 183   CRE                                             Mysore             India
# 184   MYQ                                  Mytilene (Lesbos)            Greece
# 185   MJT                                             Mzamba      South Africa
#
# [186 rows x 3 columns]

# %% [markdown]
# N

# %%
table = data.find_all('table')
table1 = table[13].find_all('td')
tabletext = [i.text for i in table1]
clean =[x for x in tabletext if len(x) > 1]

f = clean[::3]
s = clean[1::3]
t = clean[2::3]

capcode_n = pd.DataFrame(list(zip(f,s,t)), columns=['city', 'country', 'code'])
capcode_n
# Out:
#                                     city  country  code
# 0                                   Nadi     Fiji  NAN
# 1                               Nagasaki    Japan   NGS
# 2                    Nagoya - Komaki AFB    Japan   NGO
# 3                                 Nagpur    India   NAG
# 4                                Nairobi    Kenya   NBO
# ..                                   ...      ...   ...
# 68                              Novi Sad   Serbia   QND
# 69      Novosibirsk - Tolmachevo Airport   Russia   OVB
# 70                  Nürnberg (Nuremberg)  Germany   NUE
# 71                          Nuevo Laredo   Mexico   NLD
# 72  Nuku'alofa - Fua'Amotu International    Tonga   TBU
#
# [73 rows x 3 columns]

# %% [markdown]
# O

# %%
table = data.find_all('table')
table1 = table[14].find_all('td')
tabletext = [i.text for i in table1]
clean =[x for x in tabletext if len(x) > 1]

f = clean[::3]
s = clean[1::3]
t = clean[2::3]

capcode_o = pd.DataFrame(list(zip(f,s,t)), columns=['city', 'country', 'code'])
capcode_o
# Out:
#                                         city                   country  code
# 0                              Oakland (CA)                        USA  OAK
# 1                        Oaxaca - Xoxocotlan                    Mexico   OAX
# 2                                     Odense                   Denmark   ODE
# 3                                     Odessa                   Ukraine   ODS
# 4                                    Oerebro                    Sweden   ORB
# 5                                      Ohrid                 Macedonia   OHD
# 6                                       Oita                     Japan   OIT
# 7                                    Okayama                     Japan   OKJ
# 8              Okinawa, Ryukyo Island - Naha                     Japan   OKA
# 9     Oklahoma City (OK) - Will Rogers World                       USA   OKC
# 10                                     Olbia                     Italy   OLB
# ...

# %% [markdown]
# P

# %%
table = data.find_all('table')
table1 = table[15].find_all('td')
tabletext = [i.text for i in table1]
clean =[x for x in tabletext if len(x) > 1]

f = clean[::3]
s = clean[1::3]
t = clean[2::3]

capcode_p = pd.DataFrame(list(zip(f,s,t)), columns=['city', 'country', 'code'])
capcode_p
# Out:
#                                                   city             country  \
# 0                                  Paderborn/Lippstadt             Germany
# 1                                        Paducah (KY)                  USA
# 2                               Page/Lake Powell (AZ)                  USA
# 3                                            Pago Pago      American Samoa
# 4                      Pakersburg (WV) /Marietta (OH)                  USA
# ..                                                 ...                 ...
# 106                                               Pune  India, Maharashtra
# 107  Punta Arenas - Presidente Carlos Ibáñez del Ca...               Chile
# 108              Punta Cana - Punta Cana International  Dominican Republic
# 109      Pu San (Busan) - Gimhae International Airport         South Korea
# 110            Pyongyang - Sunan International Airport         North Korea
#
#      code
# 0    PAD
# 1     PAH
# 2     PGA
# 3     PPG
# 4     PKB
# ...

# %% [markdown]
# Q

# %%
table = data.find_all('table')
table1 = table[16].find_all('td')
tabletext = [i.text for i in table1]
clean =[x for x in tabletext if len(x) > 1]

f = clean[::3]
s = clean[1::3]
t = clean[2::3]

capcode_q = pd.DataFrame(list(zip(f,s,t)), columns=['city', 'country', 'code'])
capcode_q
# Out:
#                                            city             country  code
# 0                 Quebec - Quebec International              Canada  YQB
# 1                                    Queenstown           Australia   UEE
# 2                                    Queenstown         New Zealand   ZQN
# 3                                        Quetta            Pakistan   UET
# 4                                       Qingdao  Shandong, PR China   TAO
# 5                                       Quimper              France   UIP
# 6                                   Quincy (IL)                 USA   UIN
# 7  Quito - Mariscal Sucre International Airport             Ecuador   UIO

# %% [markdown]
# R

# %%
table = data.find_all('table')
table1 = table[17].find_all('td')
tabletext = [i.text for i in table1]
clean =[x for x in tabletext if len(x) > 1]

f = clean[::3]
s = clean[1::3]
t = clean[2::3]

capcode_r = pd.DataFrame(list(zip(f,s,t)), columns=['city', 'country', 'code'])
capcode_r
# Out:
#                                                  city           country  code
# 0                          Rabat - Rabat-Salé Airport           Morocco  RBA
# 1   Rahim Yar Khan - Shaikh Zayed International Ai...          Pakistan   RYK
# 2                                             Raiatea  French Polynesia   RFP
# 3                                    Rainbow Lake, AB            Canada   YOP
# 4                                              Rajkot             India   RAJ
# ..                                                ...               ...   ...
# 60                                            Rotorua       New Zealand   ROT
# 61                                          Rotterdam       Netherlands   RTM
# 62                                          Rovaniemi           Finland   RVN
# 63                                              Rundu           Namibia   NDU
# 64                                               Ruse          Bulgaria   ROU
#
# [65 rows x 3 columns]

# %% [markdown]
# S

# %%
table = data.find_all('table')
table1 = table[18].find_all('td')
tabletext = [i.text for i in table1]
clean =[x for x in tabletext if len(x) > 1]

f = clean[::3]
s = clean[1::3]
t = clean[2::3]

capcode_s = pd.DataFrame(list(zip(f,s,t)), columns=['city', 'country', 'code'])
capcode_s
# Out:
#                                   city     country  code
# 0                         Saarbruecken     Germany  SCN
# 1                     Sacramento (CA)          USA   SMF
# 2                           Sado Shima       Japan   SDS
# 3       Saginaw/Bay City/Midland (MI)          USA   MBS
# 4                         Saidu Sharif    Pakistan   SDT
# ..                                 ...         ...   ...
# 182  Suva - Nausori Airport (Luvuluvu)        Fiji   SUV
# 183                         Swakopmund     Namibia   SWP
# 184            Sydney - Sydney Airport   Australia   SYD
# 185                             Sylhet  Bangladesh   ZYL
# 186                     Syracuse (NY)          USA   SYR
#
# [187 rows x 3 columns]

# %% [markdown]
# T

# %%
table = data.find_all('table')
table1 = table[19].find_all('td')
tabletext = [i.text for i in table1]
clean =[x for x in tabletext if len(x) > 1]

f = clean[::3]
s = clean[1::3]
t = clean[2::3]

capcode_t = pd.DataFrame(list(zip(f,s,t)), columns=['city', 'country', 'code'])
capcode_t
# Out:
#                         city           country  code
# 0                      Tabuk      Saudi Arabia  TUU
# 1                       Taif      Saudi Arabia   TIF
# 2   Taipei - Chiang Kai Shek            Taiwan   TPE
# 3         Taipei - Sung Shan            Taiwan   TAY
# 4                    Taiyuan  Shanxi, PR China   TYN
# ..                       ...               ...   ...
# 89                     Turku           Finland   TKU
# 90          Tuscaloosa (AL)                USA   TCL
# 91          Tuxtla Gutierrez            Mexico   TGZ
# 92           Twin Falls (ID)               USA   TWF
# 93               Tyler (TX)                USA   TYR
#
# [94 rows x 3 columns]

# %% [markdown]
# U

# %%
table = data.find_all('table')
table1 = table[20].find_all('td')
tabletext = [i.text for i in table1]
clean =[x for x in tabletext if len(x) > 1]

f = clean[::3]
s = clean[1::3]
t = clean[2::3]

capcode_u = pd.DataFrame(list(zip(f,s,t)), columns=['city', 'country', 'code'])
capcode_u
# Out:
#                                            city  \
# 0                                       Ua Huka
# 1                                        Ua Pou
# 2                                           Ube
# 3                                       Uberaba
# 4            Uberlandia - Eduardo Gomes Airport
# 5         Ubon Ratchathani - Muang Ubon Airport
# 6                       Udaipur - Dabok Airport
# 7                         Uden - Volkel Airport
# 8                                    Udon Thani
# 9                                           Ufa
# 10                             Uherske Hradiste
# 11                                         Uige
# 12            Ujung Pandang - Hasanudin Airport
# 13                                        Ukhta
# 14                                  Ukiah (CA)
# 15            Ulaanbaatar - Buyant Uhaa Airport
# 16                                     Ulan-Ude
# 17                                      Ulanhot
# ...

# %% [markdown]
# V

# %%
table = data.find_all('table')
table1 = table[21].find_all('td')
tabletext = [i.text for i in table1]
clean =[x for x in tabletext if len(x) > 1]

f = clean[::3]
s = clean[1::3]
t = clean[2::3]

capcode_v = pd.DataFrame(list(zip(f,s,t)), columns=['city', 'country', 'code'])
capcode_v
# Out:
#                                          city                   country  code
# 0                                       Vaasa                   Finland  VAA
# 1                                     Vaexjoe                    Sweden   VXO
# 2                                  Vail (CO)                        USA   EGE
# 3                                    Val d'Or                    Canada   YVO
# 4                                Valdez (AK)                        USA   VDZ
# 5                               Valdosta (GA)                       USA   VLD
# 6                                    Valencia                     Spain   VLC
# 7                                    Valencia                 Venezuela   VLN
# 8                                  Valladolid                     Spain   VLL
# 9                                  Valparaiso                     Chile   VAP
# 10                                   Valverde                     Spain   VDE
# ...

# %% [markdown]
# W

# %%
table = data.find_all('table')
table1 = table[22].find_all('td')
tabletext = [i.text for i in table1]
clean =[x for x in tabletext if len(x) > 1]

f = clean[::3]
s = clean[1::3]
t = clean[2::3]

capcode_w = pd.DataFrame(list(zip(f,s,t)), columns=['city', 'country', 'code'])
capcode_w
# Out:
#                                                  city  \
# 0                                              Wabush
# 1                                          Waco (TX)
# 2                                               Wagga
# 3                                   Walla Walla (WA)
# 4                                              Wallis
# 5                                          Walvis Bay
# 6                                         Warrnambool
# 7                            Warsaw - Frédéric Chopin
# 8   Washington DC - Baltimore Washington Internati...
# 9                Washington DC - Dulles International
# 10             Washington DC - Ronald Reagan National
# 11                                      Washington DC
# 12                                        Waterloo IA
# 13                                    Watertown (SD)
# 14                         Wausau/Stevens Point (WI)
# 15                                              Weipa
# ...

# %% [markdown]
# XYZ

# %%
table = data.find_all('table')
table1 = table[23].find_all('td')
tabletext = [i.text for i in table1]
clean =[x for x in tabletext if len(x) > 1]

f = clean[::3]
s = clean[1::3]
t = clean[2::3]

capcode_xyz = pd.DataFrame(list(zip(f,s,t)), columns=['code', 'city', 'country'])
capcode_xyz
# Out:
#     code                              city             country
# 0    XYZ                            Xiamen    Fujian, PR China
# 1   XMN                   Xi'an - Xianyang   Shaanxi, PR China
# 2    XIY                      Yakima (WA)                  USA
# 3    YKM                     Yakutat (AK)                  USA
# 4    YAK                           Yakutsk              Russia
# 5    YKS                Yamagata, Junmachi               Japan
# 6    GAJ                      Yamoussoukro       Côte d'Ivoire
# 7    ASK                             Yanbu        Saudi Arabia
# 8    YNB     Yangon (Rangoon) - Mingaladon             Myanmar
# 9    RGN                           Yaounde            Cameroon
# 10   YAO                       Yellowknife              Canada
# 11   YZF  Yekaterinburg - Koltsovo Airport              Russia
# 12   SVX                           Yichang     Hubei, PR China
# 13   YIH                          Yokohama               Japan
# ...

# %%
df_list = [capcode_xyz,capcode_w, capcode_v, capcode_u, capcode_t, capcode_s, capcode_r, capcode_q, capcode_p, capcode_o, capcode_n, capcode_m, capcode_l, capcode_k, capcode_j, capcode_i, capcode_h, capcode_g, capcode_f, capcode_e, capcode_d, capcode_c, capcode_b, capcode_a]

# %%
iata_codes = pd.concat(df_list, ignore_index=True)
iata_codes
# Out:
#       code                                    city            country
# 0      XYZ                                  Xiamen   Fujian, PR China
# 1     XMN                         Xi'an - Xianyang  Shaanxi, PR China
# 2      XIY                            Yakima (WA)                 USA
# 3      YKM                           Yakutat (AK)                 USA
# 4      YAK                                 Yakutsk             Russia
# ...    ...                                     ...                ...
# 1981   AUR                                Aurillac             France
# 1982   AUS  Austin (TX) - Austin-Bergstrom Airport                USA
# 1983   AYW                                 Ayawasi          Indonesia
# 1984   AYQ                  Ayers Rock - Connellan          Australia
# 1985   AYR                                     Ayr          Australia
#
# [1986 rows x 3 columns]

# %%
avg_food_cost_capitals = pd.read_csv("avg_food_cost_capitals.csv")
avg_food_cost_capitals
# Out:
#                                                  label  price     city  \
# 0                          Meal Inexpensive Restaurant   1.77    Kabul
# 1    Meal for 2 People Mid-range Restaurant Three-c...  10.30    Kabul
# 2                          Meal Inexpensive Restaurant   5.14   Tirana
# 3    Meal for 2 People Mid-range Restaurant Three-c...  34.27   Tirana
# 4                          Meal Inexpensive Restaurant   2.72  Algiers
# ..                                                 ...    ...      ...
# 295  Meal for 2 People Mid-range Restaurant Three-c...  18.66    Hanoi
# 296                        Meal Inexpensive Restaurant   3.05   Lusaka
# 297  Meal for 2 People Mid-range Restaurant Three-c...  16.09   Lusaka
# 298                        Meal Inexpensive Restaurant   9.15   Harare
# 299  Meal for 2 People Mid-range Restaurant Three-c...  40.65   Harare
#
#        Countries
# 0    Afghanistan
# 1    Afghanistan
# 2        Albania
# 3        Albania
# 4        Algeria
# ...

# %%
unique_city = list(avg_food_cost_capitals['city'].unique())
len(unique_city)
unique_city[-1]
# Out:
# 'Harare'

# %%
len(iata_codes[iata_codes['city'].str.contains('Kabssul')])
# Out:
# 0

# %%
matched = []
final_code = ''
for cit in unique_city:
    code = iata_codes[iata_codes['city'].str.contains(cit)]
    if len(code) > 0:
        final_code = code['code'].values[0]
    matched.append(final_code)
    matched.append(final_code)

# %%
len(matched)
# Out:
# 300

# %%
avg_food_cost_capitals['code'] = matched
avg_food_cost_capitals
# Out:
#                                                  label  price     city  \
# 0                          Meal Inexpensive Restaurant   1.77    Kabul
# 1    Meal for 2 People Mid-range Restaurant Three-c...  10.30    Kabul
# 2                          Meal Inexpensive Restaurant   5.14   Tirana
# 3    Meal for 2 People Mid-range Restaurant Three-c...  34.27   Tirana
# 4                          Meal Inexpensive Restaurant   2.72  Algiers
# ..                                                 ...    ...      ...
# 295  Meal for 2 People Mid-range Restaurant Three-c...  18.66    Hanoi
# 296                        Meal Inexpensive Restaurant   3.05   Lusaka
# 297  Meal for 2 People Mid-range Restaurant Three-c...  16.09   Lusaka
# 298                        Meal Inexpensive Restaurant   9.15   Harare
# 299  Meal for 2 People Mid-range Restaurant Three-c...  40.65   Harare
#
#        Countries code
# 0    Afghanistan  KBL
# 1    Afghanistan  KBL
# 2        Albania  TIA
# ...

# %%
avg_food_cost_capitals[avg_food_cost_capitals['Countries'] == 'Brunei']
# Out:
#                                                 label  price  \
# 44                        Meal Inexpensive Restaurant   2.86
# 45  Meal for 2 People Mid-range Restaurant Three-c...  21.46
#
#                    city Countries code
# 44  Bandar-Seri-Begawan    Brunei  BSB
# 45  Bandar-Seri-Begawan    Brunei  BSB

# %%
avg_food_cost_capitals[avg_food_cost_capitals['city'] == 'Bangkok']
# Out:
#                                                  label  price     city  \
# 268                        Meal Inexpensive Restaurant   2.40  Bangkok
# 269  Meal for 2 People Mid-range Restaurant Three-c...  26.70  Bangkok
#
#     Countries code
# 268  Thailand  DMK
# 269  Thailand  DMK

# %%
avg_food_cost_capitals['code'][269]# = 'BKK'
# Out:
# 'DMK'

# %%
val=[]
for cit in iata_codes['city']:
    code = iata_codes[iata_codes['city'].str.contains(cit)]
    if len(code) > 0:
        val.append(i)
    else:
        pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [46], line 5
#       3 code = iata_codes[iata_codes['city'].str.contains(cit)]
#       4 if len(code) > 0:
# ----> 5     val.append(i)
#       6 else:
#       7     pass
#
# NameError: name 'i' is not defined

# %%
iata_codes[iata_codes['city'].str.contains('Bangkok')]
# Out:
#      code                                 city   country
# 1733  DMK                   Bangkok, Don Muang  Thailand
# 1734  BKK  Bangkok, Suvarnabhumi International  Thailand

# %%
condition = iata_codes['country'].value_counts() > 1
condition

# iata_codes[condition]

iata_codes['country'].value_counts()
# Out:
# USA                                                403
# Australia                                          114
# Canada                                              68
# United Kingdom                                      52
# France                                              43
#                                                   ...
# Mexico City - Santa Lucia                            1
# Mexico City - Juarez International                   1
# Mexico City - Atizapan                               1
# Mexico City - Mexico City International Airport      1
# Paraguay                                             1
# Name: country, Length: 501, dtype: int64

# %%
duplicateRows = iata_codes[iata_codes.duplicated(['country'])]

# %%
len(duplicateRows["country"].unique())
# Out:
# 135

# %%
iata_codes[iata_codes['city'].str.contains('Washington')]
# Out:
#      code                                               city country
# 32    BWI  Washington DC - Baltimore Washington Internati...     USA
# 33    IAD               Washington DC - Dulles International     USA
# 34    DCA             Washington DC - Ronald Reagan National     USA
# 35    WAS                                      Washington DC     USA
# 1725  BWI  Baltimore (MD) - Washington International Airport     USA

# %%
avg_food_cost_capitals.to_csv("food_iati_capitals.csv", index=False)
